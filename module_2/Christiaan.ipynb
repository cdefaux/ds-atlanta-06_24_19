# %% [markdown]
# ## Loops & Dictionaries (10 minutes)
# Create a nested dictionary of recipes, with keys at the top level and dictionaries as their associated values.
#
# 1. Create an empty dictionary named `recipes`.
# 1. Add three dishes as the **keys** of your dictionary (e.g. 'meat pie')
# 1. For each key, the **value** should be another dictionary consisting of `ingredient: amount` pairs. (eg `'sugar': 'two cups'`) Each dish should have three ingredients.
# 1. Write a function to process the recipe dictionary. This function should loop through the recipes and return a single list of all ingredients for all recipes.

# %%
recipes = {'mujaddara': {'lentils': '100g', 'onion': '1 chopped', 'cumin': '1 teaspoon'},
           'smoothie': {'kale': 'handful', 'banana': '2 peeled', 'blueberries': '2 cups'},
           'soup': {'tomatoes': '1 can chopped', 'carrots': '1 chopped', 'beans': '1 can'}}

for recipe in recipes.values():
    for ingredient in recipe:
        print(ingredient)
# Out:
# lentils
# onion
# cumin
# kale
# banana
# blueberries
# tomatoes
# carrots
# beans

# %% [markdown]
# ## Coding Readibility (5 Minutes)
# Rewrite the code below in using best practices:
# ```python
# def blabla():
# for i in range ( 10 ):for j in range( 10 ):for k in range(10): print( i,j,k ) return everything
# ```

# %%
def blabla():
    for i in range(10):
        for j in range(10):
            for k in range(10):
                print(i,j,k)
    return everything

# %% [markdown]
# ## Data cleaning (15 Minutes)
# read data from http://rattle.togaware.com/weatherAUS.csv
# 1. Add a `day`, `month`, and `year` column (three new columns)
# 1. Print out the name of the columns where there are missing values
# 1. Drop all columns except `day`, `month`, `year`, `Rainfall`, and `Sunshine`
# 1. Fill all missing `Rainfall` values as follows:
#   1. If `Sunshine` is over 7.0, set `Rainfall` = 0
#   2. Else (including if `Sunshine is NaN`) set `Rainfall` to the mean `Rainfall` value.

# %%
import pandas as pd
import numpy as np
import datetime

df = pd.read_csv('http://rattle.togaware.com/weatherAUS.csv')

# %%
df.shape
# Out:
# (157344, 24)

# %%
df.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1801
# MaxTemp           1593
# Rainfall          3607
# Evaporation      72731
# Sunshine         79565
# WindGustDir      11650
# WindGustSpeed    11586
# WindDir9am       11788
# WindDir3pm        5366
# WindSpeed9am      2394
# WindSpeed3pm      4183
# Humidity9am       2874
# Humidity3pm       5256
# Pressure9am      16864
# Pressure3pm      16862
# Cloud9am         63040
# Cloud3pm         67156
# Temp9am           1971
# Temp3pm           4338
# RainToday         3607
# RISK_MM           3606
# RainTomorrow      3606
# dtype: int64

# %%
df.head(300)
# Out:
#            Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1    2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2    2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3    2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4    2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5    2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6    2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7    2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8    2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9    2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 10   2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# 11   2008-12-12   Albury     15.9     21.7       2.2          NaN       NaN
# 12   2008-12-13   Albury     15.9     18.6      15.6          NaN       NaN
# 13   2008-12-14   Albury     12.6     21.0       3.6          NaN       NaN
# 14   2008-12-15   Albury      8.4     24.6       0.0          NaN       NaN
# 15   2008-12-16   Albury      9.8     27.7       NaN          NaN       NaN
# 16   2008-12-17   Albury     14.1     20.9       0.0          NaN       NaN
# 17   2008-12-18   Albury     13.5     22.9      16.8          NaN       NaN
# 18   2008-12-19   Albury     11.2     22.5      10.6          NaN       NaN
# 19   2008-12-20   Albury      9.8     25.6       0.0          NaN       NaN
# 20   2008-12-21   Albury     11.5     29.3       0.0          NaN       NaN
# 21   2008-12-22   Albury     17.1     33.0       0.0          NaN       NaN
# 22   2008-12-23   Albury     20.5     31.8       0.0          NaN       NaN
# 23   2008-12-24   Albury     15.3     30.9       0.0          NaN       NaN
# 24   2008-12-25   Albury     12.6     32.4       0.0          NaN       NaN
# 25   2008-12-26   Albury     16.2     33.9       0.0          NaN       NaN
# 26   2008-12-27   Albury     16.9     33.0       0.0          NaN       NaN
# 27   2008-12-28   Albury     20.1     32.7       0.0          NaN       NaN
# 28   2008-12-29   Albury     19.7     27.2       0.0          NaN       NaN
# 29   2008-12-30   Albury     12.5     24.2       1.2          NaN       NaN
# ..          ...      ...      ...      ...       ...          ...       ...
# 270  2009-08-28   Albury      1.1     18.6       0.0          NaN       NaN
# 271  2009-08-29   Albury      7.2     17.9       4.2          NaN       NaN
# 272  2009-08-30   Albury      6.3     11.1      13.4          NaN       NaN
# 273  2009-08-31   Albury      6.7     14.2       1.4          NaN       NaN
# 274  2009-09-01   Albury      5.1     14.2       3.0          NaN       NaN
# 275  2009-09-02   Albury      1.0     16.8       0.0          NaN       NaN
# 276  2009-09-03   Albury      6.1     20.7       0.0          NaN       NaN
# 277  2009-09-04   Albury      6.3     16.9       1.4          NaN       NaN
# 278  2009-09-05   Albury      2.1     15.0       0.0          NaN       NaN
# 279  2009-09-06   Albury      1.6     16.6       0.0          NaN       NaN
# 280  2009-09-07   Albury      8.3     17.6       0.0          NaN       NaN
# 281  2009-09-08   Albury      5.7     16.5       0.0          NaN       NaN
# 282  2009-09-09   Albury      7.5     14.3       0.0          NaN       NaN
# 283  2009-09-10   Albury      2.6      NaN       0.0          NaN       NaN
# 284  2009-09-11   Albury      NaN     18.8       NaN          NaN       NaN
# 285  2009-09-12   Albury      6.5     24.7       0.0          NaN       NaN
# 286  2009-09-13   Albury     13.2     25.1       0.0          NaN       NaN
# 287  2009-09-14   Albury      4.3     17.8       0.0          NaN       NaN
# 288  2009-09-15   Albury      1.6     17.2       0.0          NaN       NaN
# 289  2009-09-16   Albury      2.8     21.1       0.0          NaN       NaN
# 290  2009-09-17   Albury      6.3     19.0       0.0          NaN       NaN
# 291  2009-09-18   Albury      7.4     20.4      10.2          NaN       NaN
# 292  2009-09-19   Albury      5.4     20.6       0.0          NaN       NaN
# 293  2009-09-20   Albury      8.0     18.9       0.4          NaN       NaN
# 294  2009-09-21   Albury      3.7     19.0       0.2          NaN       NaN
# 295  2009-09-22   Albury     11.5     20.2       8.4          NaN       NaN
# 296  2009-09-23   Albury      9.3     16.8      28.8          NaN       NaN
# 297  2009-09-24   Albury      8.2     18.2       1.4          NaN       NaN
# 298  2009-09-25   Albury      5.3     20.6       0.0          NaN       NaN
# 299  2009-09-26   Albury      6.8     12.2       6.0          NaN       NaN
#
#     WindGustDir  WindGustSpeed WindDir9am  ... Cloud9am  Cloud3pm  Temp9am  \
# 0             W           44.0          W  ...      8.0       NaN     16.9
# 1           WNW           44.0        NNW  ...      NaN       NaN     17.2
# 2           WSW           46.0          W  ...      NaN       2.0     21.0
# 3            NE           24.0         SE  ...      NaN       NaN     18.1
# 4             W           41.0        ENE  ...      7.0       8.0     17.8
# 5           WNW           56.0          W  ...      NaN       NaN     20.6
# 6             W           50.0         SW  ...      1.0       NaN     18.1
# 7             W           35.0        SSE  ...      NaN       NaN     16.3
# 8           NNW           80.0         SE  ...      NaN       NaN     18.3
# 9             W           28.0          S  ...      NaN       NaN     20.1
# 10            N           30.0        SSE  ...      NaN       NaN     20.4
# 11          NNE           31.0         NE  ...      8.0       8.0     15.9
# 12            W           61.0        NNW  ...      8.0       8.0     17.4
# 13           SW           44.0          W  ...      NaN       7.0     15.8
# 14          NaN            NaN          S  ...      NaN       NaN     15.9
# 15          WNW           50.0        NaN  ...      0.0       NaN     17.3
# 16          ENE           22.0        SSW  ...      8.0       1.0     17.2
# 17            W           63.0          N  ...      8.0       1.0     18.0
# 18          SSE           43.0        WSW  ...      NaN       2.0     15.5
# 19          SSE           26.0         SE  ...      NaN       NaN     15.8
# 20            S           24.0         SE  ...      NaN       NaN     19.1
# 21           NE           43.0         NE  ...      NaN       1.0     24.5
# 22          WNW           41.0          W  ...      NaN       NaN     23.8
# 23            N           33.0        ESE  ...      5.0       NaN     20.9
# 24            W           43.0          E  ...      NaN       NaN     21.5
# 25          WSW           35.0         SE  ...      NaN       1.0     23.2
# 26          WSW           57.0        NaN  ...      NaN       1.0     26.6
# 27          WNW           48.0          N  ...      NaN       NaN     24.6
# 28          WNW           46.0         NW  ...      NaN       NaN     21.6
# 29          WNW           50.0        WSW  ...      8.0       8.0     12.5
# ..          ...            ...        ...  ...      ...       ...      ...
# 270         NNW           24.0        ESE  ...      NaN       NaN      7.2
# 271           W           59.0         NE  ...      1.0       8.0     13.0
# 272         WNW           56.0          W  ...      8.0       8.0      6.7
# 273          NW           39.0         NW  ...      7.0       5.0      9.7
# 274         WNW           24.0        WNW  ...      8.0       1.0      9.7
# 275         ESE           24.0        ESE  ...      NaN       NaN      7.0
# 276          NE           43.0         SE  ...      NaN       NaN     10.2
# 277          NW           35.0        ESE  ...      1.0       NaN     12.5
# 278         WNW           30.0        ESE  ...      NaN       6.0      8.6
# 279          NE           37.0         SE  ...      NaN       NaN      8.3
# 280           W           41.0        ENE  ...      NaN       NaN     13.9
# 281           W           46.0          W  ...      5.0       4.0      9.4
# 282           W           35.0          W  ...      8.0       8.0      9.5
# 283         NaN            NaN          E  ...      NaN       6.0      9.7
# 284           N           31.0         SE  ...      NaN       NaN      8.7
# 285          NE           39.0         SE  ...      NaN       NaN     13.2
# 286         NNE           35.0          E  ...      NaN       NaN     17.3
# 287          SW           24.0         NE  ...      NaN       NaN     10.9
# 288           S           20.0        ESE  ...      NaN       NaN      8.1
# 289           E           17.0          E  ...      NaN       NaN     11.2
# 290         WNW           24.0          E  ...      NaN       7.0     12.9
# 291         WNW           46.0        NaN  ...      NaN       NaN     12.9
# 292         NNW           22.0         NE  ...      8.0       8.0     10.2
# 293           W           33.0        NaN  ...      8.0       NaN     14.3
# 294          NE           43.0        ESE  ...      NaN       NaN     11.5
# 295         NNE           50.0        NNW  ...      8.0       1.0     15.5
# 296           W           56.0          W  ...      5.0       8.0     13.1
# 297          NW           41.0        WNW  ...      NaN       4.0     12.6
# 298         NNW           44.0        NNE  ...      2.0       7.0     15.2
# 299         WNW           56.0        WNW  ...      7.0       6.0      7.9
#
#      Temp3pm  RainToday  RISK_MM  RainTomorrow  day  year  month
# 0       21.8         No      0.0            No    1  2008     12
# 1       24.3         No      0.0            No    2  2008     12
# 2       23.2         No      0.0            No    3  2008     12
# 3       26.5         No      1.0            No    4  2008     12
# 4       29.7         No      0.2            No    5  2008     12
# 5       28.9         No      0.0            No    6  2008     12
# 6       24.6         No      0.0            No    7  2008     12
# 7       25.5         No      0.0            No    8  2008     12
# 8       30.2         No      1.4           Yes    9  2008     12
# 9       28.2        Yes      0.0            No   10  2008     12
# 10      28.8         No      2.2           Yes   11  2008     12
# 11      17.0        Yes     15.6           Yes   12  2008     12
# 12      15.8        Yes      3.6           Yes   13  2008     12
# 13      19.8        Yes      0.0            No   14  2008     12
# 14      23.5         No      NaN           NaN   15  2008     12
# 15      26.2        NaN      0.0            No   16  2008     12
# 16      18.1         No     16.8           Yes   17  2008     12
# 17      21.5        Yes     10.6           Yes   18  2008     12
# 18      21.0        Yes      0.0            No   19  2008     12
# 19      23.2         No      0.0            No   20  2008     12
# 20      27.3         No      0.0            No   21  2008     12
# 21      31.6         No      0.0            No   22  2008     12
# 22      30.8         No      0.0            No   23  2008     12
# 23      29.0         No      0.0            No   24  2008     12
# 24      31.2         No      0.0            No   25  2008     12
# 25      33.0         No      0.0            No   26  2008     12
# 26      31.2         No      0.0            No   27  2008     12
# 27      32.1         No      0.0            No   28  2008     12
# 28      26.1         No      1.2           Yes   29  2008     12
# 29      18.2        Yes      0.8            No   30  2008     12
# ..       ...        ...      ...           ...  ...   ...    ...
# 270     17.6         No      4.2           Yes   28  2009      8
# 271     17.5        Yes     13.4           Yes   29  2009      8
# 272     10.7        Yes      1.4           Yes   30  2009      8
# 273     13.9        Yes      3.0           Yes   31  2009      8
# 274     12.5        Yes      0.0            No    1  2009      9
# 275     16.0         No      0.0            No    2  2009      9
# 276     20.3         No      1.4           Yes    3  2009      9
# 277     15.5        Yes      0.0            No    4  2009      9
# 278     14.9         No      0.0            No    5  2009      9
# 279     15.4         No      0.0            No    6  2009      9
# 280     16.5         No      0.0            No    7  2009      9
# 281     15.3         No      0.0            No    8  2009      9
# 282     13.4         No      0.0            No    9  2009      9
# 283     14.3         No      NaN           NaN   10  2009      9
# 284     18.1        NaN      0.0            No   11  2009      9
# 285     24.0         No      0.0            No   12  2009      9
# 286     23.1         No      0.0            No   13  2009      9
# 287     17.1         No      0.0            No   14  2009      9
# 288     16.7         No      0.0            No   15  2009      9
# 289     20.7         No      0.0            No   16  2009      9
# 290     14.0         No     10.2           Yes   17  2009      9
# 291     20.3        Yes      0.0            No   18  2009      9
# 292     19.2         No      0.4            No   19  2009      9
# 293     16.8         No      0.2            No   20  2009      9
# 294     18.3         No      8.4           Yes   21  2009      9
# 295     19.2        Yes     28.8           Yes   22  2009      9
# 296     15.9        Yes      1.4           Yes   23  2009      9
# 297     17.2        Yes      0.0            No   24  2009      9
# 298     17.3         No      6.0           Yes   25  2009      9
# 299     11.1        Yes      1.6           Yes   26  2009      9
#
# [300 rows x 27 columns]

# %%
df['day'] = pd.DatetimeIndex(df['Date']).day
df['year'] = pd.DatetimeIndex(df['Date']).year
df['month'] = pd.DatetimeIndex(df['Date']).month

df1 = df[['day', 'month', 'year', 'Rainfall', 'Sunshine']]
df1.head(20)
# Out:
#     day  month  year  Rainfall  Sunshine
# 0     1     12  2008       0.6       NaN
# 1     2     12  2008       0.0       NaN
# 2     3     12  2008       0.0       NaN
# 3     4     12  2008       0.0       NaN
# 4     5     12  2008       1.0       NaN
# 5     6     12  2008       0.2       NaN
# 6     7     12  2008       0.0       NaN
# 7     8     12  2008       0.0       NaN
# 8     9     12  2008       0.0       NaN
# 9    10     12  2008       1.4       NaN
# 10   11     12  2008       0.0       NaN
# 11   12     12  2008       2.2       NaN
# 12   13     12  2008      15.6       NaN
# 13   14     12  2008       3.6       NaN
# 14   15     12  2008       0.0       NaN
# 15   16     12  2008       NaN       NaN
# 16   17     12  2008       0.0       NaN
# 17   18     12  2008      16.8       NaN
# 18   19     12  2008      10.6       NaN
# 19   20     12  2008       0.0       NaN

# %%
df1.loc[df1['Sunshine'] < 7, 'Rainfall'] = df.Rainfall.mean()
df1.loc[df1['Sunshine'] > 7, 'Rainfall'] = 0

df1.fillna(df1.Rainfall.mean())
# Out:
# /Users/christiandefaux/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#         day  month  year   Rainfall  Sunshine
# 0         1     12  2008   0.600000  1.560757
# 1         2     12  2008   0.000000  1.560757
# 2         3     12  2008   0.000000  1.560757
# 3         4     12  2008   0.000000  1.560757
# 4         5     12  2008   1.000000  1.560757
# 5         6     12  2008   0.200000  1.560757
# 6         7     12  2008   0.000000  1.560757
# 7         8     12  2008   0.000000  1.560757
# 8         9     12  2008   0.000000  1.560757
# 9        10     12  2008   1.400000  1.560757
# 10       11     12  2008   0.000000  1.560757
# 11       12     12  2008   2.200000  1.560757
# 12       13     12  2008  15.600000  1.560757
# 13       14     12  2008   3.600000  1.560757
# 14       15     12  2008   0.000000  1.560757
# 15       16     12  2008   1.560757  1.560757
# 16       17     12  2008   0.000000  1.560757
# 17       18     12  2008  16.800000  1.560757
# 18       19     12  2008  10.600000  1.560757
# 19       20     12  2008   0.000000  1.560757
# 20       21     12  2008   0.000000  1.560757
# 21       22     12  2008   0.000000  1.560757
# 22       23     12  2008   0.000000  1.560757
# 23       24     12  2008   0.000000  1.560757
# 24       25     12  2008   0.000000  1.560757
# 25       26     12  2008   0.000000  1.560757
# 26       27     12  2008   0.000000  1.560757
# 27       28     12  2008   0.000000  1.560757
# 28       29     12  2008   0.000000  1.560757
# 29       30     12  2008   1.200000  1.560757
# ...     ...    ...   ...        ...       ...
# 157314    1      3  2019   0.000000  1.560757
# 157315    2      3  2019   0.000000  1.560757
# 157316    3      3  2019   0.000000  1.560757
# 157317    4      3  2019   0.000000  1.560757
# 157318    5      3  2019   0.000000  1.560757
# 157319    6      3  2019   0.000000  1.560757
# 157320    7      3  2019   0.000000  1.560757
# 157321    8      3  2019   0.000000  1.560757
# 157322    9      3  2019   0.000000  1.560757
# 157323   10      3  2019   0.000000  1.560757
# 157324   11      3  2019   0.000000  1.560757
# 157325   12      3  2019   0.000000  1.560757
# 157326   13      3  2019   0.000000  1.560757
# 157327   14      3  2019   0.000000  1.560757
# 157328   15      3  2019   0.000000  1.560757
# 157329   16      3  2019   0.000000  1.560757
# 157330   17      3  2019   0.000000  1.560757
# 157331   18      3  2019   0.000000  1.560757
# 157332   19      3  2019   0.000000  1.560757
# 157333   20      3  2019   0.000000  1.560757
# 157334   21      3  2019   0.000000  1.560757
# 157335   22      3  2019   0.000000  1.560757
# 157336   23      3  2019   0.000000  1.560757
# 157337   24      3  2019   0.000000  1.560757
# 157338   25      3  2019   0.000000  1.560757
# 157339   26      3  2019   0.000000  1.560757
# 157340   27      3  2019   0.000000  1.560757
# 157341   28      3  2019   0.000000  1.560757
# 157342   29      3  2019   0.000000  1.560757
# 157343   30      3  2019   0.000000  1.560757
#
# [157344 rows x 5 columns]

# %% [markdown]
# ## Visualization (15 Minutes)
#
# As best you can, recreate this bar chart created in Google Sheets using Python.  You may use Matplotlib, Seaborn, or any other graphing library you came across.
# <img src="chart.jpg" alt="chart to recreate" width="500"/>

# %%
import matplotlib.pyplot as plt

data1 = {'A': 54, 'B': 23, 'C': 99, 'D': 37, 'E': 3}

df3 = pd.DataFrame(list(data1.items()), index = ['A','B','C','D','E'])

ax = df3.plot(kind='barh', title ="Count By Category",figsize=(10,8), fontsize=12)
ax.set_xlabel("Count",fontsize=12)
ax.set_ylabel("Category",fontsize=12)
# Out:
# Text(0, 0.5, 'Category')

# %% [markdown]
# ## Github (5 Minutes)
#
# Follow the instructions at https://github.com/enkeboll/fis-dc-ds-060319-gifs, and make sure to check your email to confirm your collaborator status!

# %% [markdown]
# # Assessment submission (2 Minutes)
# Please save this file as `firstname.ipynb` and upload it using [this form](https://docs.google.com/forms/d/e/1FAIpQLSdlnMgc5Nb5uFTmw7DiScapevg-VA8DQdiFeIAil5sZqYZbFA/viewform)
